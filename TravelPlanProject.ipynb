# %%
# !pip install langchain langchain_core langchain_groq langchain_community langchain
# Out:
# Requirement already satisfied: langchain in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (0.3.14)
# Requirement already satisfied: langchain_core in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (0.3.29)
# Requirement already satisfied: langchain_groq in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (0.2.3)
# Requirement already satisfied: langchain_community in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (0.3.14)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain) (0.2.10)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.2.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.10.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain_core) (4.12.2)
# Requirement already satisfied: groq<1,>=0.4.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain_groq) (0.13.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langchain_community) (2.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.24.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (0.28.1)
# Requirement already satisfied: sniffio in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from groq<1,>=0.4.1->langchain_groq) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.13)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain_groq) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (5.10.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (4.8.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.2.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.115.6)
# Requirement already satisfied: ffmpy in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.5.3 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (1.5.3)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.25.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.27.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (3.1.5)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (2.2.1)
# Requirement already satisfied: orjson~=3.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (3.10.13)
# Requirement already satisfied: packaging in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (2.10.4)
# Requirement already satisfied: pydub in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.8.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.41.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio-client==1.5.3->gradio) (2024.12.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from gradio-client==1.5.3->gradio) (14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.24.1->gradio) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (3.16.1)
# Requirement already satisfied: requests in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.25.1->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.0->gradio) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\prath\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import gradio as gr
from typing import TypedDict, Annotated, List
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

class PlannerState(TypedDict):
    messages: Annotated[List[HumanMessage | AIMessage], "The messages in the conversation"]
    city: str
    interests: List[str]
    itinerary: str


llm = ChatGroq(
    temperature=0,
    groq_api_key="",
    model_name="llama-3.3-70b-versatile"
)


itinerary_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful travel assistant. Create a day trip itinerary for {city} based on the user's interests: {interests}. Provide a brief, bulleted itinerary."),
    ("human", "Create an itinerary for my day trip."),
])

def input_city(city: str, state: PlannerState) -> PlannerState:
    return {
        **state,
        "city": city,
        "messages": state['messages'] + [HumanMessage(content=city)],
    }

def input_interests(interests: str, state: PlannerState) -> PlannerState:
    return {
        **state,
        "interests": [interest.strip() for interest in interests.split(',')],
        "messages": state['messages'] + [HumanMessage(content=interests)],
    }

def create_itinerary(state: PlannerState) -> str:
    response = llm.invoke(itinerary_prompt.format_messages(city=state['city'], interests=", ".join(state['interests'])))
    state["itinerary"] = response.content
    state["messages"] += [AIMessage(content=response.content)]
    return response.content


def travel_planner(city: str, interests: str):
   
    state = {
        "messages": [],
        "city": "",
        "interests": [],
        "itinerary": "",
    }

    state = input_city(city, state)
    state = input_interests(interests, state)

    
    itinerary = create_itinerary(state)

    return itinerary


interface = gr.Interface(
    fn=travel_planner,
    theme='Yntec/HaleyCH_Theme_Orange_Green',
    inputs=[
        gr.Textbox(label="Enter the city for your day trip"),
        gr.Textbox(label="Enter your interests (comma-separated)"),
    ],
    outputs=gr.Textbox(label="Generated Itinerary"),
    title="Travel Itinerary Planner",
    description="Enter a city and your interests to generate a personalized day trip itinerary."
)


interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
